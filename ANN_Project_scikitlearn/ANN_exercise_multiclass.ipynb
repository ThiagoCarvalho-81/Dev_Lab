# %% [markdown]
# # Artificial Neural Networks - Multi-Class approach
#
#
# ### Perform a thorough data analysis and design a neural network to classify eletrical appliances into different mutually excluse kinds.
#
#
# ### DATASET
# Was provided a csv dabatase with 100 appliences, observed 200 times and labeled with their current class.
#
# ### GOAL
# Create a model able to evaluate the results of transient signals from electrical appliances (signals obtained in a 2s window when the appliance is switched on) in order to classify them into 7 different classes.
#
# ### ANALYSIS STAGES:
# 1) Load the data and perform data cleaning (if necessary)<br>
# 2) Visualize the data for comprehension <br>
# 3) Transform the labels into a multi-class correct representation<br>
# 4) Prepare the data to be presented to ML<br>
# 5) Build the neural network with its respective parameters<br>
# 6) Test and validate the results<br>
# 7) Evaluate the use of PCA (Principal Component Analysis)<br>
# 8) Conclusion<br>

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.datasets import make_classification
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## TASK 1 - Load the data and perform data cleaning
#
# ### Acquiring data from the csv file
#
# This data is outdated, it does not necessarily represent the current appliances. But, these studies are still current and continue to use AI features in their solutions

# %%
db = pd.read_csv('db.csv')
db
# Out:
#        t0     t1     t2     t3     t4     t5     t6     t7     t8     t9  ...  \
# 0   24.00  24.00  23.00  25.00  24.00  25.00  24.00  24.00  22.00  25.00  ...
# 1   23.00  23.00  22.00  21.00  21.00  22.00  23.00  23.00  22.00  21.00  ...
# 2   -0.55  -0.55  -0.55   3.45  13.45  11.45  18.45  18.45  20.45  20.45  ...
# 3   12.30  10.30  15.30  15.30  16.30  15.30  17.30  16.30  17.30  15.30  ...
# 4   24.85   2.85   5.85  -1.15   2.85  -1.15   1.85  -1.15   0.85  -1.15  ...
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 95  14.70   4.70   2.70  -0.30   0.70   0.70   2.70   1.70   1.70   0.70  ...
# 96  11.55   5.55   2.55   1.55   0.55   1.55   0.55   0.55  -0.45   0.55  ...
# 97  14.35   4.35   1.35   2.35  -0.65   0.35   0.35   1.35   0.35   0.35  ...
# 98  22.70  -5.30  -0.30  -5.30  -1.30  -3.30  -1.30  -3.30  -2.30  -3.30  ...
# 99  -5.30  -6.30  -6.30  -6.30  -5.30  -3.30  -4.30  -6.30  -6.30  -4.30  ...
#
#     t191  t192  t193  t194  t195  t196  t197  t198  t199  Classes
# 0   1.00 -1.00  1.00 -1.00  1.00  0.00  1.00  0.00  0.00        1
# 1  -1.00  1.00  0.00  1.00 -1.00  0.00 -1.00  1.00  0.00        1
# 2  -0.55  0.45 -0.55  0.45 -0.55  0.45 -0.55  0.45 -0.55        1
# 3  -0.70  0.30 -0.70  0.30 -0.70  1.30 -0.70  1.30 -0.70        1
# 4  -0.15  0.85 -1.15 -0.15 -1.15  0.85 -0.15  0.85 -0.15        2
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...      ...
# 95 -0.30 -0.30 -0.30  0.70 -0.30  0.70 -1.30 -1.30 -0.30        5
# 96  0.55 -0.45  0.55 -1.45  0.55 -0.45  0.55 -0.45  0.55        6
# 97 -0.65  0.35 -0.65  0.35 -1.65  0.35  0.35  0.35 -0.65        6
# 98 -2.30  1.70 -1.30  1.70 -0.30  0.70 -2.30  0.70 -1.30        7
# 99 -0.30  0.70 -1.30 -0.30  2.70  1.70 -0.30 -0.30 -0.30        7
#
# [100 rows x 201 columns]

# %%
db.info
# Out:
# <bound method DataFrame.info of        t0     t1     t2     t3     t4     t5     t6     t7     t8     t9  ...  \
# 0   24.00  24.00  23.00  25.00  24.00  25.00  24.00  24.00  22.00  25.00  ...
# 1   23.00  23.00  22.00  21.00  21.00  22.00  23.00  23.00  22.00  21.00  ...
# 2   -0.55  -0.55  -0.55   3.45  13.45  11.45  18.45  18.45  20.45  20.45  ...
# 3   12.30  10.30  15.30  15.30  16.30  15.30  17.30  16.30  17.30  15.30  ...
# 4   24.85   2.85   5.85  -1.15   2.85  -1.15   1.85  -1.15   0.85  -1.15  ...
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 95  14.70   4.70   2.70  -0.30   0.70   0.70   2.70   1.70   1.70   0.70  ...
# 96  11.55   5.55   2.55   1.55   0.55   1.55   0.55   0.55  -0.45   0.55  ...
# 97  14.35   4.35   1.35   2.35  -0.65   0.35   0.35   1.35   0.35   0.35  ...
# 98  22.70  -5.30  -0.30  -5.30  -1.30  -3.30  -1.30  -3.30  -2.30  -3.30  ...
# 99  -5.30  -6.30  -6.30  -6.30  -5.30  -3.30  -4.30  -6.30  -6.30  -4.30  ...
#
#     t191  t192  t193  t194  t195  t196  t197  t198  t199  Classes
# 0   1.00 -1.00  1.00 -1.00  1.00  0.00  1.00  0.00  0.00        1
# 1  -1.00  1.00  0.00  1.00 -1.00  0.00 -1.00  1.00  0.00        1
# 2  -0.55  0.45 -0.55  0.45 -0.55  0.45 -0.55  0.45 -0.55        1
# 3  -0.70  0.30 -0.70  0.30 -0.70  1.30 -0.70  1.30 -0.70        1
# 4  -0.15  0.85 -1.15 -0.15 -1.15  0.85 -0.15  0.85 -0.15        2
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...      ...
# 95 -0.30 -0.30 -0.30  0.70 -0.30  0.70 -1.30 -1.30 -0.30        5
# 96  0.55 -0.45  0.55 -1.45  0.55 -0.45  0.55 -0.45  0.55        6
# 97 -0.65  0.35 -0.65  0.35 -1.65  0.35  0.35  0.35 -0.65        6
# 98 -2.30  1.70 -1.30  1.70 -0.30  0.70 -2.30  0.70 -1.30        7
# 99 -0.30  0.70 -1.30 -0.30  2.70  1.70 -0.30 -0.30 -0.30        7
#
# [100 rows x 201 columns]>

# %%
db.groupby(['Classes']).count()
# Out:
#          t0  t1  t2  t3  t4  t5  t6  t7  t8  t9  ...  t190  t191  t192  t193  \
# Classes                                          ...
# 1        16  16  16  16  16  16  16  16  16  16  ...    16    16    16    16
# 2        22  22  22  22  22  22  22  22  22  22  ...    22    22    22    22
# 3        30  30  30  30  30  30  30  30  30  30  ...    30    30    30    30
# 4         8   8   8   8   8   8   8   8   8   8  ...     8     8     8     8
# 5        16  16  16  16  16  16  16  16  16  16  ...    16    16    16    16
# 6         4   4   4   4   4   4   4   4   4   4  ...     4     4     4     4
# 7         4   4   4   4   4   4   4   4   4   4  ...     4     4     4     4
#
#          t194  t195  t196  t197  t198  t199
# Classes
# 1          16    16    16    16    16    16
# 2          22    22    22    22    22    22
# 3          30    30    30    30    30    30
# 4           8     8     8     8     8     8
# 5          16    16    16    16    16    16
# 6           4     4     4     4     4     4
# 7           4     4     4     4     4     4
#
# [7 rows x 200 columns]

# %%
db.groupby(['Classes']).mean()
# Out:
#                 t0         t1         t2         t3         t4         t5  \
# Classes
# 1        13.306250  12.681250  15.931250  16.806250  17.931250  17.181250
# 2         2.227273   1.045455   1.409091   0.318182   0.954545   0.409091
# 3        12.740000  12.006667  12.273333  11.073333  10.406667   9.606667
# 4         8.550000   2.800000   4.300000   2.550000   3.800000   3.050000
# 5        19.518750  12.018750   8.268750   7.518750   6.268750   6.018750
# 6        12.950000   4.950000   1.950000   1.950000  -0.050000   0.950000
# 7         8.700000  -5.800000  -3.300000  -5.800000  -3.300000  -3.300000
#
#                 t6         t7         t8         t9  ...      t190      t191  \
# Classes                                              ...
# 1        17.681250  19.306250  20.931250  20.306250  ...  0.056250 -0.443750
# 2         0.863636   0.409091   0.863636   0.136364  ...  0.136364  0.136364
# 3         9.740000   8.873333   8.606667   8.073333  ...  0.006667  0.940000
# 4         4.550000   3.300000   4.050000   3.050000  ...  0.550000 -0.450000
# 5         5.768750   5.768750   4.893750   4.893750  ...  0.143750 -0.231250
# 6         0.450000   0.950000  -0.050000   0.450000  ... -0.050000 -0.050000
# 7        -2.800000  -4.800000  -4.300000  -3.800000  ...  1.200000 -1.300000
#
#              t192      t193      t194      t195      t196      t197      t198  \
# Classes
# 1        0.181250 -0.068750  0.306250 -0.318750  0.306250 -0.193750  0.431250
# 2       -0.045455 -0.136364  0.227273 -0.045455  0.136364 -0.318182 -0.045455
# 3       -0.393333 -0.193333  0.073333  0.206667  0.673333 -0.260000 -0.593333
# 4        0.550000 -0.200000  0.050000 -0.950000  0.550000 -0.450000  0.800000
# 5       -0.856250  0.143750  0.143750  0.393750  0.018750  0.268750 -0.606250
# 6       -0.050000 -0.050000 -0.550000 -0.550000 -0.050000  0.450000 -0.050000
# 7        1.200000 -1.300000  0.700000  1.200000  1.200000 -1.300000  0.200000
#
#              t199
# Classes
# 1       -0.318750
# 2       -0.045455
# 3       -0.193333
# 4       -0.450000
# 5        0.018750
# 6       -0.050000
# 7       -0.800000
#
# [7 rows x 200 columns]

# %% [markdown]
# ## TASK 2 - Visualize the data for comprehension
#
# ### Preparing the data for plotting a histogram

# %%
Classe1 = pd.DataFrame(db[db['Classes']==1])
Classe1.drop('Classes', axis = 1, inplace=True)
Classe_1 = pd.Series(Classe1.values.ravel('F'))

# %%
Classe2 = pd.DataFrame(db[db['Classes']==2])
Classe2.drop('Classes', axis = 1, inplace=True)
Classe_2 = pd.Series(Classe2.values.ravel('F'))

# %%
Classe3 = pd.DataFrame(db[db['Classes']==3])
Classe3.drop('Classes', axis = 1, inplace=True)
Classe_3 = pd.Series(Classe3.values.ravel('F'))

# %%
Classe4 = pd.DataFrame(db[db['Classes']==4])
Classe4.drop('Classes', axis = 1, inplace=True)
Classe_4 = pd.Series(Classe4.values.ravel('F'))

# %%
Classe5 = pd.DataFrame(db[db['Classes']==5])
Classe5.drop('Classes', axis = 1, inplace=True)
Classe_5 = pd.Series(Classe5.values.ravel('F'))

# %%
Classe6 = pd.DataFrame(db[db['Classes']==6])
Classe6.drop('Classes', axis = 1, inplace=True)
Classe_6 = pd.Series(Classe6.values.ravel('F'))

# %%
Classe7 = pd.DataFrame(db[db['Classes']==7])
Classe7.drop('Classes', axis = 1, inplace=True)
Classe_7 = pd.Series(Classe7.values.ravel('F'))

# %%
print(f'**** CLASSE 1 **** Observations: {int(len(Classe_1)/200)} * 200  | Mean: {round(np.mean(Classe_1),2)}  | Median: {round(np.median(Classe_1),2)} | Standard deviation: {round(np.std(Classe_1),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_1, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_1, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe1)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_1')
fig.show()

#################################

print(f'**** CLASSE 2 **** Observations: {int(len(Classe_2)/200)} * 200  | Mean: {round(np.mean(Classe_2),2)}  | Median: {round(np.median(Classe_2),2)}  | Standard deviation: {round(np.std(Classe_2),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_2, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_2, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe2)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_2')
fig.show()

#################################

print(f'**** CLASSE 3 **** Observations: {int(len(Classe_3)/200)} * 200  | Mean: {round(np.mean(Classe_3),2)} | Median: {round(np.median(Classe_3),2)} | Standard deviation: {round(np.std(Classe_3),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_3, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_3, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe3)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_3')
fig.show()

#################################

print(f'**** CLASSE 4 **** Observations:  {int(len(Classe_4)/200)} * 200  | Mean: {round(np.mean(Classe_4),2)} | Median: {round(np.median(Classe_4),2)} | Standard deviation: {round(np.std(Classe_4),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_4, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_4, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe4)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_4')
fig.show()

#################################

print(f'**** CLASSE 5 **** Observations: {int(len(Classe_5)/200)} * 200  | Mean: {round(np.mean(Classe_5),2)} | Median: {round(np.median(Classe_5),2)} | Standard deviation: {round(np.std(Classe_5),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_5, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_5, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe5)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_5')
fig.show()

#################################

print(f'**** CLASSE 6 **** Observations:  {int(len(Classe_6)/200)} * 200  | Mean: {round(np.mean(Classe_6),2)} | Median: {round(np.median(Classe_6),2)} | Standard deviation: {round(np.std(Classe_6),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_6, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_6, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe6)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_6')
fig.show()

#################################

print(f'**** CLASSE 7 **** Observations:  {int(len(Classe_7)/200)} * 200  | Mean: {round(np.mean(Classe_7),2)} | Median: {round(np.median(Classe_7),2)} | Standard deviation: {round(np.std(Classe_7),2)}')

fig, ax = plt.subplots(1, 3, figsize = (16,4))

n, bins, patches = ax[0].hist(Classe_7, 50, density=True, facecolor='g', alpha=0.75)
ax[0].set_xlabel('Signal result')
ax[0].grid(True)

ax[1].boxplot(Classe_7, vert=False)
ax[1].set_title('')
ax[1].set_xlabel('Signal result')
ax[1].set_ylabel('')

ax[2].boxplot(Classe7)
ax[2].set_ylabel('Signal result')
ax[2].set_xlabel('200 observations - From T0 --------> T199')

fig.suptitle('Classe_7')
fig.show()
# Out:
# **** CLASSE 1 **** Observations: 16 * 200  | Mean: 4.1  | Median: 0.45 | Standard deviation: 8.18
# **** CLASSE 2 **** Observations: 22 * 200  | Mean: 0.1  | Median: 0.1  | Standard deviation: 1.08
# **** CLASSE 3 **** Observations: 30 * 200  | Mean: 1.69 | Median: 0.65 | Standard deviation: 3.87
# **** CLASSE 4 **** Observations:  8 * 200  | Mean: 1.73 | Median: 1.05 | Standard deviation: 2.57
# **** CLASSE 5 **** Observations: 16 * 200  | Mean: 0.82 | Median: 0.25 | Standard deviation: 3.14
# **** CLASSE 6 **** Observations:  4 * 200  | Mean: 0.13 | Median: 0.35 | Standard deviation: 1.17
# **** CLASSE 7 **** Observations:  4 * 200  | Mean: -1.1 | Median: -1.3 | Standard deviation: 3.21

# %% [markdown]
# ## TASK 3 - Transforming the labels into a multi-class correct representation

# %%
# Transforming classes into dummies
db['Classes'] = 'Class ' + db['Classes'].astype(str)

# %%
# Separating x and y, where y gets the dummied columns and X the rest of the dataframe without the dummied columns
y = db[['Classes']]
x = db.drop(['Classes'], axis=1)

# %% [markdown]
# ## TASK 4 - Preparing the data to be presented to ML

# %%
# Standardizing the x-values
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
# Splitting training and testing databases
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, random_state=1, test_size=0.3)

# %% [markdown]
# ## TASK 5 - Build the neural network with its respective parameters
# ### Searching for the best parameters combination (Grid Searching)

# %%
#parameters = {'hidden_layer_sizes':range(1,100,20), 'activation':('identity', 'logistic', 'tanh', 'relu'), #'solver':('lbfgs', 'sgd', 'adam'), 'learning_rate_init': (0.001, 0.002)}

# %%
#clf_grid = MLPClassifier(max_iter=300, random_state=1, validation_fraction=0.1, verbose=True)
#gridmodel = GridSearchCV(clf_grid, parameters)
#gridmodel.fit(x_train, y_train)
#print(gridmodel.best_estimator_)
#model = gridmodel.best_estimator_
# Out:
#  55, loss = 0.12429503
# Iteration 56, loss = 0.11999388
# Iteration 57, loss = 0.11593957
# Iteration 58, loss = 0.11214888
# Iteration 59, loss = 0.10852992
# Iteration 60, loss = 0.10506081
# Iteration 61, loss = 0.10175932
# Iteration 62, loss = 0.09860293
# Iteration 63, loss = 0.09560664
# Iteration 64, loss = 0.09278994
# Iteration 65, loss = 0.09008255
# Iteration 66, loss = 0.08750161
# Iteration 67, loss = 0.08501199
# Iteration 68, loss = 0.08263247
# Iteration 69, loss = 0.08035784
# Iteration 70, loss = 0.07819585
# Iteration 71, loss = 0.07612466
# Iteration 72, loss = 0.07413116
# Iteration 73, loss = 0.07221443
# Iteration 74, loss = 0.07037332
# Iteration 75, loss = 0.06860408
# Iteration 76, loss = 0.06690265
# Iteration 77, loss = 0.06527474
# Iteration 78, loss = 0.06370230
# Iteration 79, loss = 0.06219274
# Iteration 80, loss = 0.06073191
# Iteration 81, loss = 0.05933595
# Iteration 82, loss = 0.05798298
# Iteration 83, loss = 0.05671820
# Iteration 84, loss = 0.05550303
# Iteration 85, loss = 0.05432813
# Iteration 86, loss = 0.05319911
# Iteration 87, loss = 0.05209802
# Iteration 88, loss = 0.05102939
# Iteration 89, loss = 0.04999187
# Iteration 90, loss = 0.04898891
# Iteration 91, loss = 0.04800281
# Iteration 92, loss = 0.04703848
# Iteration 93, loss = 0.04612873
# Iteration 94, loss = 0.04525569
# Iteration 95, loss = 0.04440891
# Iteration 96, loss = 0.04359372
# Iteration 97, loss = 0.04279496
# Iteration 98, loss = 0.04201761
# Iteration 99, loss = 0.04126333
# Iteration 100, loss = 0.04053403
# Iteration 170, loss = 0.01662533
# Iteration 171, loss = 0.01645683
# Iteration 172, loss = 0.01628985
# Iteration 173, loss = 0.01612700
# Iteration 174, loss = 0.01596703
# Iteration 175, loss = 0.01580946
# Iteration 176, loss = 0.01565315
# Iteration 177, loss = 0.01549802
# Iteration 178, loss = 0.01534698
# Iteration 179, loss = 0.01519873
# Iteration 180, loss = 0.01505277
# Iteration 181, loss = 0.01490848
# Iteration 182, loss = 0.01476567
# Iteration 183, loss = 0.01462588
# Iteration 184, loss = 0.01448834
# Iteration 185, loss = 0.01435226
# Iteration 186, loss = 0.01421809
# Iteration 187, loss = 0.01408532
# Iteration 188, loss = 0.01395637
# Iteration 189, loss = 0.01382852
# Iteration 190, loss = 0.01370188
# Iteration 191, loss = 0.01357692
# Iteration 192, loss = 0.01345403
# Iteration 193, loss = 0.01333149
# Iteration 194, loss = 0.01321297
# Iteration 195, loss = 0.01309593
# Iteration 196, loss = 0.01297986
# Iteration 197, loss = 0.01286458
# Iteration 198, loss = 0.01275196
# Iteration 199, loss = 0.01264080
# Iteration 200, loss = 0.01253053
# Iteration 201, loss = 0.01242263
# Iteration 202, loss = 0.01231631
# Iteration 203, loss = 0.01221103
# Iteration 204, loss = 0.01210617
# Iteration 205, loss = 0.01200395
# Iteration 206, loss = 0.01190324
# Iteration 207, loss = 0.01180318
# Iteration 208, loss = 0.01170489
# Iteration 209, loss = 0.01160793
# Iteration 210, loss = 0.01151212
# Iteration 211, loss = 0.01141742
# Iteration 212, loss = 0.01132447
# Iteration 213, loss = 0.01123210
# Iteration 214, loss = 0.01114088
# Iteration 215, loss = 0.01105069
# Iteration 216, loss = 0.01096196
# Iteration 217, loss = 0.01087502
# Iteration 218, loss = 0.01078882
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='logistic', hidden_layer_sizes=61, max_iter=300,
#               random_state=1, solver='lbfgs', verbose=True)

# %%
model = MLPClassifier(activation='logistic', hidden_layer_sizes=61, max_iter=300, random_state=1, solver='lbfgs', verbose=True)

# %%
model.fit(x_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=61, max_iter=300,
#               random_state=1, solver='lbfgs', verbose=True)

# %%
model.predict(x_test)
# Out:
# array(['Class 6', 'Class 1', 'Class 3', 'Class 1', 'Class 4', 'Class 1',
#        'Class 3', 'Class 2', 'Class 5', 'Class 1', 'Class 2', 'Class 3',
#        'Class 2', 'Class 7', 'Class 2', 'Class 3', 'Class 2', 'Class 2',
#        'Class 3', 'Class 3', 'Class 3', 'Class 3', 'Class 5', 'Class 2',
#        'Class 4', 'Class 5', 'Class 2', 'Class 1', 'Class 2', 'Class 3'],
#       dtype='<U7')

# %% [markdown]
# ## TASK 6  - Test and validate the results

# %%
# Model's accuracy test
model.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
plot_confusion_matrix(model, x_test, y_test, cmap='RdPu',xticks_rotation='vertical' )  
plt.show()

# %%
yhat = model.predict(x_test)
print('****** Model Results ******')

print("Accuracy: ", round(metrics.accuracy_score(y_test, yhat),2))
print(metrics.classification_report(y_test, yhat, digits=2))
# Out:
# ****** Model Results ******
# Accuracy:  0.93
#               precision    recall  f1-score   support
#
#      Class 1       1.00      1.00      1.00         5
#      Class 2       0.78      1.00      0.88         7
#      Class 3       1.00      1.00      1.00         9
#      Class 4       1.00      1.00      1.00         2
#      Class 5       1.00      0.60      0.75         5
#      Class 6       1.00      1.00      1.00         1
#      Class 7       1.00      1.00      1.00         1
#
#     accuracy                           0.93        30
#    macro avg       0.97      0.94      0.95        30
# weighted avg       0.95      0.93      0.93        30

# %% [markdown]
# ## TASK 7 - Evaluate the use of PCA (Principal Component Analysis)

# %%
pca = PCA().fit(x_train)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance');

# %%
pca = PCA(n_components=0.87)
pca.fit(x_train)
x_pca_train = pca.transform(x_train)

# %%
print(f'Original Model dimensionality: {x_train.shape}')
print(f'PCA Model dimensionality: {x_pca_train.shape}')
# Out:
# Original Model dimensionality(70, 200)
# PCA Model dimensionality(70, 11)

# %%
#clf_grid_PCA = MLPClassifier(max_iter=300, random_state=1, validation_fraction=0.1, verbose=True)
#gridmodel_PCA = GridSearchCV(clf_grid_PCA, parameters)
#gridmodel_PCA.fit(x_pca_train, y_train)
#print(gridmodel_PCA.best_estimator_)
#model_PCA = gridmodel_PCA.best_estimator_

# %%
model_PCA = MLPClassifier(activation='logistic', hidden_layer_sizes=61, max_iter=300, random_state=1, solver='lbfgs', verbose=True)

# %%
model_PCA.fit(x_pca_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=61, max_iter=300,
#               random_state=1, solver='lbfgs', verbose=True)

# %%
# PCA's accuracy test
x_pca_test = pca.transform(x_test)
model_PCA.predict(x_pca_test)
model_PCA.score(x_pca_test,y_test)
# Out:
# 0.9333333333333333

# %%
plot_confusion_matrix(model_PCA, x_pca_test, y_test, cmap='Blues',xticks_rotation='vertical' )  
plt.show()

# %%
yhat1 = model_PCA.predict(x_pca_test)

print('****** PCA Model Results ******')

print("Accuracy: ", round(metrics.accuracy_score(y_test, yhat1),2))
print(metrics.classification_report(y_test, yhat1, digits=2))
# Out:
# ****** PCA Model Results ******
# Accuracy:  0.93
#               precision    recall  f1-score   support
#
#      Class 1       1.00      1.00      1.00         5
#      Class 2       0.78      1.00      0.88         7
#      Class 3       1.00      1.00      1.00         9
#      Class 4       1.00      1.00      1.00         2
#      Class 5       1.00      0.60      0.75         5
#      Class 6       1.00      1.00      1.00         1
#      Class 7       1.00      1.00      1.00         1
#
#     accuracy                           0.93        30
#    macro avg       0.97      0.94      0.95        30
# weighted avg       0.95      0.93      0.93        30

# %% [markdown]
# ## TASK 8 - Conclusion
#
# Using gridsearch to look for optimal parameters, an artificial neural network was identified. This model brings accuracy of 0.93 for the desired multi-class classification purpose with the following parameters:
#
# #### activation function ='logistic' | hidden_layer_sizes = 61 | max_iterations = 300 | solver ='lbfgs'
#
#
# The PCA with 87% reduction in dimensionality from 200 to 11 components brought no loss of model accuracy as plots the confusion matrices above.
